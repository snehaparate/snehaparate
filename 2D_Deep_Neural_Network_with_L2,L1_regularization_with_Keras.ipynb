# %% [markdown]
# # Deep Neural Network with L2 /L1 Regularization using Keras

# %%
import tensorflow as tf

from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers

import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
random.seed(42)         # Initialize the random number generator.
np.random.seed(42)      # With the seed reset, the same set of numbers will appear every time.
#tf.set_random_seed(42)  # sets the graph-level random seed

# %% [markdown]
# ## Dataset

# %%
# Use the MNIST dataset  of Keras.

mnist = tf.keras.datasets.mnist

(Xtrain, Ytrain) , (Xtest, Ytest) = mnist.load_data()

# size of the datsets

print(Xtrain.shape)
print(Xtest.shape)
print(Ytrain.shape)
print(Ytest.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28)
# (10000, 28, 28)
# (60000,)
# (10000,)

# %%
# Normalize the data
# 60000 input images are in the train set.
# 10000 input images are in the test set.

Xtrain = Xtrain.reshape((60000, 28*28))    # reshape the input set to size 28*28.
Xtrain = Xtrain.astype('float32')/255      # normalize to grayscale; set datatype as float32

Xtest = Xtest.reshape((10000, 28*28))      # reshape the input set to size 28*28.
Xtest = Xtest.astype('float32')/255        # normalize to grayscale; set datatype as float32

Ytrain = tf.keras.utils.to_categorical(Ytrain)
Ytest = tf.keras.utils.to_categorical(Ytest)

# %% [markdown]
# ## DNN Model

# %% [markdown]
# Using Keras, create the DNN or Sequential Model

# %%
# Create a model object

dnnModel = models.Sequential()

# %% [markdown]
# Add dense layers, specifying the number of units in each layer and the activation function used in the layer.

# %%
# Layer 1 = input layer
# specify the input size for in the first layer.

dnnModel.add(layers.Dense(50, activation='relu', input_shape= (28*28,)))

# Layer 2 = hidden layer  with Regularizers
dnnModel.add(layers.Dense(60, activation='relu', kernel_regularizer=regularizers.l2(0.01),
                activity_regularizer=regularizers.l2(0.01)) )

# Layer 3 = hidden layer
dnnModel.add(layers.Dense(30, activation='relu'))

# Layer 4 = output layer
dnnModel.add(layers.Dense(10, activation='softmax'))

dnnModel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                39250
#
#  dense_1 (Dense)             (None, 60)                3060
#
#  dense_2 (Dense)             (None, 30)                1830
#
#  dense_3 (Dense)             (None, 10)                310
#
# =================================================================
# Total params: 44450 (173.63 KB)
# Trainable params: 44450 (173.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Regularization and Optimizations of DNN

# %%
# Configure  the model for training, by using appropriate optimizers and regularizations
# Available optimizer: adam, rmsprop, adagrad, sgd
# loss:  objective that the model will try to minimize.
# Available loss: categorical_crossentropy, binary_crossentropy, mean_squared_error
# metrics: List of metrics to be evaluated by the model during training and testing.

dnnModel.compile( optimizer = 'adam', loss = 'categorical_crossentropy', metrics=['accuracy'] )

# %% [markdown]
# ## Train the Model

# %%
# train the model

h = dnnModel.fit( Xtrain, Ytrain, epochs=25, validation_split=0.2, batch_size=64)
# Out:
# Epoch 1/25
# 750/750 [==============================] - 2s 2ms/step - loss: 0.7162 - accuracy: 0.8717 - val_loss: 0.2923 - val_accuracy: 0.9493
# Epoch 2/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.2461 - accuracy: 0.9518 - val_loss: 0.1992 - val_accuracy: 0.9603
# Epoch 3/25
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1754 - accuracy: 0.9645 - val_loss: 0.1787 - val_accuracy: 0.9606
# Epoch 4/25
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1426 - accuracy: 0.9704 - val_loss: 0.1527 - val_accuracy: 0.9649
# Epoch 5/25
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1220 - accuracy: 0.9753 - val_loss: 0.1561 - val_accuracy: 0.9630
# Epoch 6/25
# 750/750 [==============================] - 1s 2ms/step - loss: 0.1091 - accuracy: 0.9771 - val_loss: 0.1314 - val_accuracy: 0.9692
# Epoch 7/25
# 750/750 [==============================] - 1s 2ms/step - loss: 0.0973 - accuracy: 0.9804 - val_loss: 0.1414 - val_accuracy: 0.9660
# Epoch 8/25
# 750/750 [==============================] - 2s 2ms/step - loss: 0.0903 - accuracy: 0.9814 - val_loss: 0.1473 - val_accuracy: 0.9632
# Epoch 9/25
# 750/750 [==============================] - 2s 2ms/step - loss: 0.0830 - accuracy: 0.9829 - val_loss: 0.1467 - val_accuracy: 0.9644
# Epoch 10/25
# 750/750 [==============================] - 2s 2ms/step - loss: 0.0770 - accuracy: 0.9844 - val_loss: 0.1266 - val_accuracy: 0.9695
# Epoch 11/25
# 750/750 [==============================] - 2s 2ms/step - loss: 0.0726 - accuracy: 0.9852 - val_loss: 0.1263 - val_accuracy: 0.9720
# Epoch 12/25
# 750/750 [==============================] - 2s 2ms/step - loss: 0.0675 - accuracy: 0.9866 - val_loss: 0.1279 - val_accuracy: 0.9718
# Epoch 13/25
# 750/750 [==============================] - 1s 2ms/step - loss: 0.0627 - accuracy: 0.9882 - val_loss: 0.1421 - val_accuracy: 0.9663
# Epoch 14/25
# 750/750 [==============================] - 1s 2ms/step - loss: 0.0643 - accuracy: 0.9864 - val_loss: 0.1384 - val_accuracy: 0.9691
# Epoch 15/25
# 750/750 [==============================] - 2s 2ms/step - loss: 0.0634 - accuracy: 0.9875 - val_loss: 0.1492 - val_accuracy: 0.9668
# Epoch 16/25
# 750/750 [==============================] - 2s 2ms/step - loss: 0.0598 - accuracy: 0.9886 - val_loss: 0.1327 - val_accuracy: 0.9715
# Epoch 17/25
# 750/750 [==============================] - 2s 2ms/step - loss: 0.0543 - accuracy: 0.9898 - val_loss: 0.1401 - val_accuracy: 0.9687
# Epoch 18/25
# 750/750 [==============================] - 1s 2ms/step - loss: 0.0528 - accuracy: 0.9899 - val_loss: 0.1434 - val_accuracy: 0.9662
# Epoch 19/25
# 750/750 [==============================] - 2s 2ms/step - loss: 0.0525 - accuracy: 0.9897 - val_loss: 0.1417 - val_accuracy: 0.9687
# Epoch 20/25
# 750/750 [==============================] - 2s 2ms/step - loss: 0.0466 - accuracy: 0.9918 - val_loss: 0.1359 - val_accuracy: 0.9712
# Epoch 21/25
# 750/750 [==============================] - 1s 2ms/step - loss: 0.0504 - accuracy: 0.9905 - val_loss: 0.1384 - val_accuracy: 0.9704
# Epoch 22/25
# 750/750 [==============================] - 1s 2ms/step - loss: 0.0488 - accuracy: 0.9912 - val_loss: 0.1524 - val_accuracy: 0.9663
# Epoch 23/25
# 750/750 [==============================] - 2s 2ms/step - loss: 0.0482 - accuracy: 0.9914 - val_loss: 0.1372 - val_accuracy: 0.9687
# Epoch 24/25
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0460 - accuracy: 0.9919 - val_loss: 0.1541 - val_accuracy: 0.9658
# Epoch 25/25
# 750/750 [==============================] - 2s 2ms/step - loss: 0.0383 - accuracy: 0.9939 - val_loss: 0.1489 - val_accuracy: 0.9681

# %%
print('Final training loss \t', h.history['loss'][-1])
print('Final training accuracy ', h.history['accuracy'][-1])
# Out:
# Final training loss 	 0.03834455460309982
# Final training accuracy  0.9939166903495789

# %%
# plot the training loss

plt.plot(h.history['loss'], label='Train loss')
plt.plot(h.history['val_loss'], label='Val loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Plot of Training Loss')
plt.legend()
plt.show()

# %%
# plot the training accuracy

plt.plot(h.history['accuracy'], label='Train Acc')
plt.plot(h.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Plot of Training Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Testing the Model

# %%
# testing the model

testLoss, testAccuracy = dnnModel.evaluate( Xtest, Ytest)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1418 - accuracy: 0.9687

# %%
print('Testing loss \t', testLoss)
print('Testing accuracy ', testAccuracy)
# Out:
# Testing loss 	 0.14179454743862152
# Testing accuracy  0.9686999917030334

# %% [markdown]
# Modify the code to get a better testing accuracy.
# - Change the number of hidden units
# - Increase the number of hidden layers
# - Use a different optimizer
